# %% [markdown]
# <h4>Data Ingestion</h4>

# %%
from langchain_core.documents import Document

# %%
doc = Document(
    page_content = "This is the main text that I am using to create the RAG",
    metadata = {
        "Source":"example.txt",
        "pages":1,
        "author":"Amit Singh",
        "date":"25-07-2026"
    }
)
doc
# Out:
# Document(metadata={'Source': 'example.txt', 'pages': 1, 'author': 'Amit Singh', 'date': '25-07-2026'}, page_content='This is the main text that I am using to create the RAG')

# %%
import os
os.makedirs("../data/text_files", exist_ok=True)

# %%
sample_texts={
    "../data/text_files/tester.txt":"""Python Programming Introduction

Python is such a versatile language — it’s like the Swiss Army knife of programming. You can use it for everything from web development and data science to machine learning and even automation tasks. Its readability and huge ecosystem of libraries make it one of the most beginner-friendly yet powerful languages out there.

Here are a few areas where Python really shines:

Web frameworks like Django and Flask let you build scalable websites quickly.

Data analysis with libraries such as Pandas and NumPy makes handling large datasets straightforward.
""",
    
    "../data/text_files/long_doc.txt": """The best machine learning frameworks and tools in 2026 balance research flexibility, enterprise scalability, and production readiness. For cutting-edge research, PyTorch dominates; for enterprise deployment, TensorFlow and Vertex AI lead; while Hugging Face and LangChain simplify access to pre-trained models and RAG workflows.

Key Frameworks & Tools in 2026
PyTorch
Best for research and rapid prototyping
Research Leader
Flexible Design
Dynamic computation graph makes experimentation fast. Dominates academic research and supports most state-of-the-art NLP and vision models.
Less mature for enterprise production compared to TensorFlow.
TensorFlow
Best for enterprise production ML
Enterprise Ready
Cross-Platform
Robust deployment ecosystem with TensorFlow Serving, Lite, and JS. Strong integration with Google Cloud and edge devices.
Steeper learning curve for beginners.
JAX
    
    """

}

for filepath, content in sample_texts.items():
    with open(filepath,'w') as f:
        f.write(content)

print("Sample text files creates")
# Out:
# Sample text files creates

# %%
from langchain_community.document_loaders import TextLoader

loader = TextLoader("../data/text_files/tester.txt")
document = loader.load()
print(document)
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_9148\515125641.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import TextLoader
# ...

# %%
from langchain_community.document_loaders import DirectoryLoader

dir_loaders = DirectoryLoader(
    "../data/text_files",
    glob = "**/*.txt",
    loader_cls = TextLoader,
    show_progress=False
)

documents = dir_loaders.load()
documents
# Out:
# [Document(metadata={'source': '..\\data\\text_files\\long-doc.txt'}, page_content='The best machine learning frameworks and tools in 2026 balance research flexibility, enterprise scalability, and production readiness. For cutting-edge research, PyTorch dominates; for enterprise deployment, TensorFlow and Vertex AI lead; while Hugging Face and LangChain simplify access to pre-trained models and RAG workflows.\n\nðŸ”‘ Key Frameworks & Tools in 2026\nPyTorch\nBest for research and rapid prototyping\nResearch Leader\nFlexible Design\nDynamic computation graph makes experimentation fast. Dominates academic research and supports most state-of-the-art NLP and vision models.\nLess mature for enterprise production compared to TensorFlow.\nTensorFlow\nBest for enterprise production ML\nEnterprise Ready\nCross-Platform\nRobust deployment ecosystem with TensorFlow Serving, Lite, and JS. Strong integration with Google Cloud and edge devices.\nSteeper learning curve for beginners.\nJAX\nBest for h
# ...

# %%
from langchain_community.document_loaders import PyPDFLoader, PyMuPDFLoader

## load all the text files from the directory
dir_loader=DirectoryLoader(
    "../data/pdf",
    glob="**/*.pdf", ## Pattern to match files  
    loader_cls= PyMuPDFLoader, ##loader class to use
    show_progress=False

)

pdf_documents=dir_loader.load()
pdf_documents
# Out:
# [Document(metadata={'producer': '', 'creator': 'Google', 'creationdate': '', 'source': '..\\data\\pdf\\Feature Engineering.pptx.pdf', 'file_path': '..\\data\\pdf\\Feature Engineering.pptx.pdf', 'total_pages': 38, 'format': 'PDF 1.4', 'title': 'Feature Engineering.pptx', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 0}, page_content='Copyright Intellipaat. All rights reserved.\nModule 1 – Feature Engineering'),
# ...

# %%
type(pdf_documents[0])
# Out:
# langchain_core.documents.base.Document

# %%
from langchain_google_community import GoogleDriveLoader

# %%
from langchain_community.document_loaders import UnstructuredFileIOLoader

loader = GoogleDriveLoader(
    folder_id="1FL7tiZ1cc_jXJKCPBOnK4WPysWhmzTVR",
    token_path="../credentials/token.json",
    # Optional: configure whether to recursively fetch files from subfolders. Defaults to False.
    loader_cls=UnstructuredFileIOLoader,
    recursive=False
)

# %%
docs = loader.load()

# %%
docs
# Out:
# []

# %%
loader = GoogleDriveLoader(
    folder_id="1FL7tiZ1cc_jXJKCPBOnK4WPysWhmzTVR",
    token_path="../credentials/token.json",
    # Optional: configure whether to recursively fetch files from subfolders. Defaults to False.
    file_types=["sheet"],
    recursive=False
)

# %%
docs = loader.load()
print("Sheet docs:", len(docs))
print(docs)
# Out:
# Sheet docs: 0
# []
